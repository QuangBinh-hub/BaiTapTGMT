# %%
# Import lớp Image
from PIL import Image
from img import *
from IPython.display import display # to display images

# %%
my_path = 'D:/TKWeb/6_TranQuangBinh_21DTH2_Buoi7/Image/1.jpg'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333>

# %%
print(img.size)
# Out:
# (500, 333)

# %%
new_size = (1000,1000)
new_image = img.resize(new_size)
display(new_image)

img.save('D:/TKWeb/6_TranQuangBinh_21DTH2_Buoi7/Image/new1.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %%
# Thay đổi kích thước
thumbnail_size = (50,50)
img.thumbnail(thumbnail_size)
display(img)
# Task: lưu ảnh
img.save('D:/TKWeb/6_TranQuangBinh_21DTH2_Buoi7/Image/new2.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=50x33>
