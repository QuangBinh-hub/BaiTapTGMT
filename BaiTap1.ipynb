# %%
from PIL import Image

# %%
import os
print(os.getcwd())
directory= 'D:/TKWeb/6_TranQuangBinh_21DTH2_Buoi7/Image'
# Out:
# C:\Users\admin\BtThiGiacMT

# %%
image_path = directory +'/1.jpg'
print(image_path)
# Out:
# D:/TKWeb/6_TranQuangBinh_21DTH2_Buoi7/Image/1.jpg

# %%
if os.path.exists(image_path):
    img01 = Image.open(image_path)
    img01.show()
else:
    print(f"Tệp không tồn tại tại đường dẫn: {image_path}")
# Out:
# Tệp không tồn tại tại đường dẫn: D:/TKWeb/6_TranQuangBinh_21DTH2_Buoi7/Image/1.jpg

# %%
img01 = Image.open(image_path)

# %%
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333>

# %%
print("Định dang ảnh: ", img01.format)
# Out:
# Định dang ảnh:  JPEG

# %%
print("Kích thước hình ảnh: ", img01.size)
# Out:
# Kích thước hình ảnh:  (500, 333)

# %%
new_img_01_path = directory + '/1.JPG'
new_img_png_01_path = directory + '/new_01.PNG'
img01.save(new_img_01_path)
img01.save(new_img_png_01_path)

# %%
img01.close()
